# %%
# =========== Q1

list_a = [1]
list_b = [2]
list_c = [7]
t = (list_a, list_b)
# print(t)
# print(list_c)
list_c = list_b
# print(list_c)

# print(t[0])
print(list_b)
print(list_c)

list_b.append(8)
list_b.append(40)
list_c.append(3)
print(list_b)
print(list_c)

# list_b[0: 5] = [4 , 5]

print(t)

# %%
# =========== Q2

data = {'x':{'y':[1,2,{'z':3}]}}
value = data['x']['y'][2]['z']
print(type(data))
print(value)

# %%
# =========== Q3

lst = [1,2,3]

lst[len(lst):] = lst

print(lst)
# Out:
# [1, 2, 3, 1, 2, 3]

# %%
# =========== Q4

lst = [1,2,3,4,5]

lst[ : :2] = [0,0,0]

print(lst)
# Out:
# [0, 2, 0, 4, 0]

# %%
# =========== Q5

t = ([1,2],[3,4])

t[0][:] = [5,6]

print(t[0])
# Out:
# [5, 6]

# %%
# =========== Q6

my_tuple_3 = (10, 12, 8 , 9, 22, 22, 20, 5, 11)

x = list(my_tuple_3)

x[2] = 100

my_tuple_3 = tuple(x)

print(my_tuple_3)
# Out:
# (10, 12, 100, 9, 22, 22, 20, 5, 11)

# %%
# =========== Q7

x = [1,2,3]

y = (x,x)

x.append(4)

print(y[0][-1])
# Out:
# 4

# %%
# =========== Q8

t = (1,2,[3,4])

t[2].extend([5])

print(t[-1][-2])
# Out:
# 4

# %%
# =========== Q9

a = {1,2,3}
b = {3,2,1}
print(a)
print(b)

print(id(a))
print(id(b))

c = a == b
print(c)  #True

d = a is b
print(d) #False
# Out:
# {1, 2, 3}
# {1, 2, 3}
# 1620081661248
# 1620081661920
# True
# False

# %%
# =========== Q10

a = [10,20]
b = [10,20]

c = b

c.append(30)

# print(a == b)

print((a == b) is not (a is b))
# Out:
# False
# False

# %%
# =========== Q11

a = {'a' , 'b' , 'c' , 'a'}

a.add('z')

a.update(['w', 'e' , 's' , 'd' , 'f'])

a.remove('a')

print(a)
# Out:
# {'c', 'b', 'f', 'z', 'w', 'e', 'd', 's'}

# %%
# =========== Q12

a = 15

b = 3

print(~a)
# Out:
# -16

# %%
# =========== Q13

set_1 = {1,2,3}

set_2 = set_1

x = list(set_2)
x.append(1000)

set_2 = set(x)
print(set_2)
print(set_1)

set_2.add(10)
print(set_2)
print(set_1)
# Out:
# {1000, 1, 2, 3}
# {1, 2, 3}
# {1, 2, 3, 1000, 10}
# {1, 2, 3}

# %%
# =========== Q14

a = {1 ,(2,('x','y'))}
# b = {1 ,{2,3}}
# c = {[1,2],[3,4]}
d = {(1,2):'value'}
# e = set([[1],[2]])

# %%
# =========== Q15

x = (1,2,[3,4])

x[2].append(5)

print(x)
# Out:
# (1, 2, [3, 4, 5])

# %%
# =========== Q16

print(list(range(10,0,-2)))
# Out:
# [10, 8, 6, 4, 2]

# %%
# =========== Q17

nums = [1,2,3,4,5,6]

print(nums[5])

for i in range(6):
    print(nums[5])
    # if nums[4] % 3 == 0:
    #     nums.pop(i)
# Out:
# 6
# 6
# 6
# 6
# 6
# 6
# 6

# %%
# =========== Q18

data = {
    'a':10,
    'b':20,
    'c':30
}

for k in data:

    print(k)
# Out:
# a
# b
# c

# %%
# =========== Q19

# %%
# =========== Q20
